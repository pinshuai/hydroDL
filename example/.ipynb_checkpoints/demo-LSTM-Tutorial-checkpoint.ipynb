# %% [markdown]
# # LSTM Tutorial for SMAP Soil Moisture
#
# This is a tutorial for training and testing a LSTM model for SMAP soil moisture prediction over CONUS.

# %% [markdown]
# ## Training part

# %% [markdown]
# - **Load needed packages**

# %%
import sys
sys.path.append('../')
import os
import torch
import numpy as np
from hydroDL.master import default, wrapMaster, train
from hydroDL.data import dbCsv
from hydroDL.post import plot, stat
from hydroDL import master
# Out:
# loading package hydroDL

# %% [markdown]
# - **Define training options**

# %%
cDir = os.getcwd()
# define training options
optData = default.update(
    default.optDataSMAP,
    rootDB=os.path.join(cDir, 'data'),
    subset='CONUSv4f1',
    tRange=[20150401, 20160401])
if torch.cuda.is_available():
    optModel = default.optLstm
else:
    optModel = default.update(
        default.optLstm,
        name='hydroDL.model.rnn.CpuLstmModel')
optLoss = default.optLossRMSE
# define epoch para
optTrain = default.update(
    default.optTrainSMAP, 
#     nEpoch=100,
    nEpoch = 5,
    saveEpoch=1
)
out = os.path.join(cDir, 'output', 'CONUSv4f1')
masterDict = wrapMaster(out, optData, optModel, optLoss, optTrain)

# %% [markdown]
# - **Train the LSTM model**

# %%
train(masterDict)
# Out:
# /Users/shua784/Dropbox/github/hydroDL/example/data/Subset/CONUSv4f1.csv
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2015/SMAP_AM.csv 0.07497906684875488
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2015/APCP_FORA.csv 0.05328798294067383
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2015/DLWRF_FORA.csv 0.07898998260498047
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2015/DSWRF_FORA.csv 0.05420708656311035
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2015/TMP_2_FORA.csv 0.043521881103515625
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2015/SPFH_2_FORA.csv 0.04923295974731445
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2015/VGRD_10_FORA.csv 0.05595517158508301
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2015/UGRD_10_FORA.csv 0.05729818344116211
# write master file /Users/shua784/Dropbox/github/hydroDL/example/output/CONUSv4f1/master.json
# Epoch 1 Loss 0.724 time 82.75
# Epoch 2 Loss 0.606 time 84.10
# Epoch 3 Loss 0.570 time 81.22
# Epoch 4 Loss 0.541 time 80.68
# Epoch 5 Loss 0.526 time 82.79

# %% [markdown]
# ## Testing part
#
# **This part is for model test and result plotting. By default the model will be saved in [here](output/CONUSv4f1/).**

# %% [markdown]
#  - **Define test option**

# %%
out = os.path.join(cDir, 'output', 'CONUSv4f1')
rootDB = os.path.join(cDir, 'data')
# nEpoch = 100
nEpoch = 1
tRange = [20160401, 20170401]

# %% [markdown]
#  - **Test the model in another year**

# %%
df, yp, yt = master.test(
    out, tRange=[20160401, 20170401], subset='CONUSv4f1', epoch=nEpoch, reTest=True)
yp = yp.squeeze()
yt = yt.squeeze()
# Out:
# read master file /Users/shua784/Dropbox/github/hydroDL/example/output/CONUSv4f1/master.json
# read master file /Users/shua784/Dropbox/github/hydroDL/example/output/CONUSv4f1/master.json
# output files: ['/Users/shua784/Dropbox/github/hydroDL/example/output/CONUSv4f1/CONUSv4f1_20160401_20170401_ep1_SMAP_AM.csv']
# Runing new results
# /Users/shua784/Dropbox/github/hydroDL/example/data/Subset/CONUSv4f1.csv
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2016/SMAP_AM.csv 0.06716299057006836
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2016/APCP_FORA.csv 0.04977607727050781
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2016/DLWRF_FORA.csv 0.04566669464111328
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2016/DSWRF_FORA.csv 0.06444501876831055
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2016/TMP_2_FORA.csv 0.04498100280761719
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2016/SPFH_2_FORA.csv 0.04583621025085449
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2016/VGRD_10_FORA.csv 0.07782912254333496
# read /Users/shua784/Dropbox/github/hydroDL/example/data/CONUSv4f1/2016/UGRD_10_FORA.csv 0.04578518867492676
# batch 0
# read master file /Users/shua784/Dropbox/github/hydroDL/example/output/CONUSv4f1/master.json

# %% [markdown]
#  - **Calculate statistic metrics.**

# %% [markdown]
# best ubRMSE is near 0.028

# %%
# calculate statistics
statErr = stat.statError(yp, yt)
# Box plots to show the test results
statDictLst = [statErr]
keyLst=['Bias', 'RMSE', 'ubRMSE', 'Corr']
dataBox = list()
for iS in range(len(keyLst)):
    statStr = keyLst[iS]
    temp = list()
    for k in range(len(statDictLst)):
        data = statDictLst[k][statStr]
        data = data[~np.isnan(data)]
        temp.append(data)
    dataBox.append(temp)
# %matplotlib inline
fig = plot.plotBoxFig(dataBox, label1=keyLst, sharey=False, figsize=(12, 5))
fig.patch.set_facecolor('white')
fig.show()
# Out:
# /Users/shua784/anaconda3/envs/DL/lib/python3.7/site-packages/scipy/stats/stats.py:3399: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/shua784/anaconda3/envs/DL/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# - **Plot an interactive map and users can click on map to show time series of observation and model predictions.**

# %%
dataGrid = [statErr['RMSE'], statErr['Corr']]
dataTs = [yp, yt]
t = df.getT()
crd = df.getGeo()
mapNameLst = ['RMSE', 'Correlation']
tsNameLst = ['LSTM', 'SMAP']
colorMap = None
colorTs = None
# plot map and time series
# %matplotlib inline
plot.plotTsMap(
    dataGrid,
    dataTs,
    lat=crd[0],
    lon=crd[1],
    t=t,
    mapNameLst=mapNameLst,
    tsNameLst=tsNameLst,
    isGrid=True)
